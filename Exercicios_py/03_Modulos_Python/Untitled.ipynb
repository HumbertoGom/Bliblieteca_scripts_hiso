# %% [markdown]
# essa linha cria uma variável `pi`

# %% [markdown]
# # esse é o título#

# %%
pi=3.14

# %% [markdown]
# essa linha cria função de circunferencia

# %%
def circun(pi,r):
    return 2*pi*r
